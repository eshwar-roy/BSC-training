# %% [markdown]
# - Q1  You want an AI model to explain, in your own words, the difference between Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI. Write a complete prompt that asks the AI to explain these four concepts as layered ideas, using one real-world example for each, in language suitable for a first-year college student.
#
# -  Q2 Write a prompt asking an AI model to explain how it processes a user's prompt, describing the stages of tokenization, understanding context, and predicting the next tokens, using a simple analogy a non-technical person would understand.
# -  Q3 You want to understand why an AI model does not simply 'search and copy' answers from the internet. Write a prompt requesting a clear explanation of how an LLM actually generates a response, including the role of probability in choosing the next word.
# -  Q4 Write a prompt asking the AI to explain what a 'context window' is, why it has a limit, and what happens when a conversation exceeds that limit. Ask for the explanation to include a simple numeric example.
# - Q5 Draft a prompt that asks the AI to compare 'Training' and 'Inference' side by side in a two-column format, describing what happens in each phase and when each one occurs.
# - Q6 Write two versions of a prompt asking 'What is Machine Learning?' — one vague/poor version and one improved version that adds a role, an audience, and a request for a real-world example. Explain in one sentence why the second version would produce a better response.

# %% [markdown]
# ### Q2 Prompt
#
# Explain how an AI processes a user's prompt by tokenizing, understanding context, and predicting next tokens, similar to how a chef reads a recipe (ingredients, steps, expected dish) to cook a meal.
#
# ---

# %% [markdown]
# ### Q3 Prompt
#
# Explain how an LLM generates a response by predicting the most probable next word based on its training data, rather than directly searching and copying information from the internet.
#
# ---

# %% [markdown]
# ### Q4 Prompt
#
# Explain what a 'context window' is (like a short-term memory limit for conversations) and why it has a limit. Illustrate with a simple example: if the limit is 100 words and a conversation exceeds 100, older parts are forgotten.
#
# ---

# %% [markdown]
# ### Q5 Prompt
#
# Compare 'Training' and 'Inference' in a two-column format. Training is when the AI learns from data to build knowledge, and inference is when it applies that knowledge to new problems after being trained.
#
# | Feature        | Training                                  | Inference                                      |
# | :------------- | :---------------------------------------- | :--------------------------------------------- |
# | **What it is** | The process of an AI model learning from data. | The process of an AI model making predictions or decisions on new data. |
# | **When it occurs** | Before deployment, when the model is built. | During runtime, when the model is used.        |
#
# ---

# %% [markdown]
# ### Q6 Prompt
#
# **Vague/Poor Prompt:** What is Machine Learning?
#
# **Improved Prompt:** Explain Machine Learning to a high school student, acting as a science tutor, and provide a real-world example of how it's used in everyday life. The second version is better because it provides clear guidance on the role, audience, and expected output, leading to a more tailored and useful response.
#
# ---

# %% [markdown]
# ### Q7 Prompt
#
# **Role:** You are a technology consultant.
#
# **Task:** Explain 'Cloud Computing' clearly and concisely.
#
# **Context:** Your audience is a non-technical business owner who needs to understand the benefits and basic concept without jargon.
#
# **Instructions:**
# - Focus on analogies that relate to common business operations.
# - Highlight the main advantages for a business.
#
# **Constraints:**
# - Maximum 150 words.
# - Avoid technical terms like 'virtualization', 'scalability', or 'IaC'.
#
# **Output Format:** A short memo or email explaining cloud computing.
#
# ---

# %% [markdown]
# ### Q8 Prompt
#
# **Role:** You are a project manager.
#
# **Audience:** Your manager.
#
# **Purpose:** Update on the 'Alpha Project' status, specifically highlighting a recent delay.
#
# **Word Limit:** 100 words.
#
# **Tone:** Professional and solution-oriented.
#
# ---

# %% [markdown]
# ### Q9 Prompt
#
# **Role:** Act as an experienced HR Manager.
#
# **Task:** Draft a short policy note (under 100 words) about work-from-home guidelines, emphasizing flexibility and productivity expectations.
#
# ---

# %% [markdown]
# ### Q10 Prompt
#
# **Context:** You are a final-year engineering student, passionate about sustainable energy solutions, with a strong academic record in renewable technologies and practical experience from an internship at a solar power company. You're preparing for a job interview at GreenTech Innovations.
#
# **Task:** Help me answer the interview question: 'Tell me about yourself.'
#
# ---

# %% [markdown]
# ### Q11 Prompt
#
# **Task:** Explain 'Blockchain Technology'.
#
# **Constraints:** Exactly 80 words, using no technical jargon.
#
# ---

# %% [markdown]
# ### Q12 Prompt Template
#
# **Template:**
#
# ```
# [ROLE]: Act as a [describe the persona, e.g., 'seasoned expert in quantum physics', 'friendly elementary school teacher'].
#
# [TASK]: Explain [technical topic, e.g., 'Artificial Neural Networks', 'Relational Databases'].
#
# [CONTEXT]: Your audience is [audience type, e.g., 'a group of high school students', 'an executive board with limited technical knowledge'].
#
# [INSTRUCTIONS]: [Specific instructions for the explanation, e.g., 'Use a real-world analogy', 'Break it down into three key points'].
#
# [CONSTRAINTS]: [Any limitations, e.g., 'Keep it under 200 words', 'Do not use any equations'].
#
# [FORMAT]: [Desired output format, e.g., 'A bulleted list', 'A short paragraph with a concluding summary'].
# ```
#
# ---

# %% [markdown]
# ### Q13 Prompt
#
# Classify the following review as Positive, Negative, or Neutral: "The delivery was fast, but the packaging was damaged."
#
# ---

# %% [markdown]
# ### Q14 Prompt
#
# **Example:**
# Customer Feedback: "The product arrived ahead of schedule and works perfectly."
# Classification: Compliment
#
# **New Feedback:**
# Customer Feedback: "I waited three weeks for this order, and it's missing parts."
# Classification:
#
# ---

# %% [markdown]
# ### Q15 Prompt
#
# Classify the tone of the following sentences as Formal or Informal:
#
# **Examples:**
# - "Could you please provide the report?" -> Formal
# - "Hey, can you send the report?" -> Informal
# - "The quarterly earnings report will be distributed shortly." -> Formal
#
# **New Sentences:**
# - "Let's grab a coffee to discuss the project." ->
# - "Kindly confirm your availability for the meeting." ->
#
# ---

# %% [markdown]
# ### Q16 Prompt
#
# Summarize the following text, focusing on the main arguments presented. Use triple dashes (---) as delimiters around the text block.
#
# ---
# The recent study on urban planning highlights the critical need for integrated public transport systems to combat traffic congestion and reduce carbon emissions. It found that cities with well-developed metro and bus networks experienced a 25% decrease in private vehicle usage. Furthermore, the study emphasized the importance of pedestrian-friendly infrastructure, noting a direct correlation between walkability scores and local business vitality. The financial implications are substantial, with an estimated annual saving of $500 per resident in fuel and maintenance costs in cities adopting these measures.
# ---
#
# Delimiters reduce confusion for the model by clearly indicating the start and end of the text it needs to process separately from the instructions.
#
# ---

# %% [markdown]
# ### Q17 Prompt Refinement
#
# a) **Poor Prompt:** Explain databases.
#
# b) **Improved Prompt:** As a senior software engineer, explain what a database is to a non-technical marketing team, using simple business language.
#
# c) **Final Version:** As a senior software engineer, explain what a database is to a non-technical marketing team, using simple business language. Keep the explanation under 150 words and present it as a short email summary.
#
# ---

# %% [markdown]
# ### Q18 Prompt
#
# **Role:** Act as a Career Counsellor.
#
# **Context:** I am a university student who enjoys problem-solving, excels in mathematics and statistics, and has a strong interest in environmental conservation, but I also like working with people. I'm looking for career paths that combine these interests.
#
# **Task:** Recommend three suitable career paths for me, explaining why each path aligns with my background and interests.
#
# ---

# %% [markdown]
# ### Q19 Prompt
#
# Solve the following problem step by step: A shop offers a 15% discount on a product priced at $3,500. After the discount, a 5% tax is added to the discounted price. What is the final amount to be paid?
#
# ---

# %% [markdown]
# ### Q20 Prompt
#
# Solve the following problem using two different approaches and then select the most reliable final answer: A car travels at an average speed of 60 km/h for the first 2 hours and then at 80 km/h for the next 3 hours. What is the total distance traveled?
#
# ---

# %% [markdown]
# ### Q21 Prompt
#
# **Step-Back Principle:** Why can two products with seemingly identical features have vastly different prices?
#
# **Application:** Apply this principle to explain the price difference between a generic brand smartphone and a leading brand smartphone, both with similar technical specifications.
#
# ---

# %% [markdown]
# ### Q22 Prompt Decomposition: Social Media Marketing Plan for a New Bakery
#
# 1.  **Prompt 1 (Target Audience & Branding):** "Identify the primary target audience for a new artisan bakery specializing in sourdough bread and unique pastries. Based on this, suggest three core brand values and a suitable brand voice for social media."
# 2.  **Prompt 2 (Platform Strategy & Content Pillars):** "Considering the target audience and brand values from the previous step, recommend the top two social media platforms for the bakery and suggest three content pillars for each platform (e.g., behind-the-scenes, product spotlights, customer engagement)."
# 3.  **Prompt 3 (Engagement & Growth Tactics):** "Propose three specific engagement tactics (e.g., contests, Q&A sessions) and two growth strategies (e.g., local influencer collaborations, paid ads targeting specific demographics) for the selected social media platforms."
# 4.  **Prompt 4 (Measurement & KPIs):** "Outline key performance indicators (KPIs) to measure the success of the social media marketing efforts, including metrics for reach, engagement, and conversion, and suggest how to track them."
#
# ---

# %% [markdown]
# ### Q23 Prompt Chain
#
# 1.  **Prompt 1 (Extract Key Points):** "Extract the 5 most crucial key points from the following article, focusing on the main arguments and conclusions.
#     [Insert a long research article here]
#     "
# 2.  **Prompt 2 (Summarize Key Points):** "Using only the key points extracted in the previous step, write a concise summary of the article, approximately 100-150 words."
# 3.  **Prompt 3 (Presentation Outline):** "Based on the summary from the previous step, create a 5-slide presentation outline. For each slide, provide a main title and 2-3 bullet points highlighting key information."
#
# ---

# %% [markdown]
# ### Q24 Prompt
#
# **Question:** Explain the concept of 'quantum entanglement' to a curious high school student.
#
# **Self-Reflection:** Review your explanation for factual errors, missing information, and unclear explanations. Specifically, check if the analogy used is effective and if the language is truly accessible. Provide an improved version of your explanation.
#
# ---

# %% [markdown]
# ### Q25 Prompt
#
# **Task (Draft Email):** Draft a short apology email to a client named 'Ms. Evelyn Reed' for a delayed delivery of 'Project Phoenix'. State that the new delivery date is 'next Tuesday, October 26th', and offer a 10% discount on their next order.
#
# **Critique & Revise:** Review the drafted email for:
# 1.  **Tone:** Is it genuinely apologetic and professional?
# 2.  **Clarity:** Is the new delivery date and compensation clear?
# 3.  **Conciseness:** Can any parts be shortened without losing meaning?
#
# Then, produce a revised version of the email incorporating these critiques.
#
# ---

# %% [markdown]
# ### Q26 Prompt
#
# **Role:** Professional Content Writer
#
# **Task:** Write a 300-word LinkedIn post announcing a new AI training program at Cambridge Infotech.
#
# **Audience:** Working professionals interested in upskilling in AI.
#
# **Key Information to Include:**
# -   Program Name: 'AI Mastery for Professionals'
# -   Focus: Practical, hands-on skills in Machine Learning, Deep Learning, and Generative AI.
# -   Benefits: Career advancement, expert instructors, flexible learning options (online/part-time).
# -   Call to Action: 'Enroll now' or 'Learn more on our website'.
#
# **Tone:** Inspirational, professional, and results-oriented.
#
# ---

# %% [markdown]
# ### Q27 Prompt
#
# Condense the following long research article into exactly 5 bullet points, focusing only on the key findings and ignoring background information, methodology, or literature review sections.
#
# [Insert a long research article text here]
#
# ---

# %% [markdown]
# ### Q28 Prompt
#
# Classify the following customer support messages into 'Complaint', 'Inquiry', or 'Feedback'. Return only the category for each message.
#
# 1.  "My new laptop isn't turning on, and I just bought it yesterday."
# 2.  "Could you tell me if the new software update is compatible with my older device model?"
# 3.  "I really appreciate the quick response from your support team; they resolved my issue efficiently."
# 4.  "The subscription renewal process was confusing and led to an unexpected charge."
# 5.  "I suggest adding a dark mode option to your mobile application."
#
# ---

# %% [markdown]
# ### Q29 Prompt
#
# Extract the Name, Job Title, Years of Experience, and Key Skills from the following candidate profile:
#
# "Sarah Chen, a Senior Data Scientist with 7 years of experience in machine learning model development and deployment. Her key skills include Python, SQL, AWS, and advanced statistical analysis."
#
# ---

# %% [markdown]
# ### Q30 Prompt
#
# Translate the following paragraph about renewable energy into Hindi, preserving technical terms like 'solar panel' and 'wind turbine', but using natural, everyday language for the rest of the text.
#
# "Renewable energy sources, such as solar panels and wind turbines, are crucial for combating climate change. They produce electricity without emitting greenhouse gases, offering a sustainable alternative to fossil fuels. Investing in these technologies is essential for a greener future."
#
# ---

# %% [markdown]
# ### Q31 Prompt
#
# Take the casual message: "hey can u pls send the report by tmrw eod, thanks" and rewrite it in three different tones:
#
# 1.  **Professional Tone:**
# 2.  **Friendly Tone:**
# 3.  **Formal Tone:**
#
# ---

# %% [markdown]
# ### Q32 Prompt
#
# **Background Information:**
# "The Amazon rainforest is the largest tropical rainforest in the world, covering much of northwestern Brazil and extending into Peru, Colombia, Ecuador, Bolivia, Guyana, Suriname, and French Guiana. It is renowned for its immense biodiversity, housing millions of species of insects, plants, and animals, and plays a critical role in regulating the Earth's climate by absorbing vast amounts of carbon dioxide."
#
# **Question:** According to the provided text, what is the primary role of the Amazon rainforest in regulating Earth's climate?
#
# ---

# %% [markdown]
# ### Q33 Prompt
#
# Explain the advantages of remote work in exactly 6 bullet points, with no additional explanation before or after the list.
#
# ---

# %% [markdown]
# ### Q34 Prompt
#
# Compare 'Machine Learning' and 'Deep Learning' in a table with the following columns: Definition, Data Requirement, and Typical Use Case.
#
# ---

# %% [markdown]
# ### Q35 Prompt
#
# Extract structured candidate information from the following resume paragraph into a JSON object. The JSON schema should include the fields `name`, `role`, `experience_years`, and `skills` (as an array of strings).
#
# "Dr. Anya Sharma is a Lead AI Researcher with 10 years of experience in natural language processing and computer vision. Her expertise lies in Python, TensorFlow, PyTorch, and large-scale data analysis."
#
# ---

# %% [markdown]
# ### Q36 Prompt
#
# Extract the same candidate information as in Q35 from the following resume paragraph, but return it as an XML object, using appropriate opening and closing tags.
#
# "Dr. Anya Sharma is a Lead AI Researcher with 10 years of experience in natural language processing and computer vision. Her expertise lies in Python, TensorFlow, PyTorch, and large-scale data analysis."
#
# ---

# %% [markdown]
# ### Q37 Prompt
#
# Extract product review data from the following text based on the schema `product_name`, `rating` (1-5 stars), `sentiment` (positive/negative/neutral), and `main_complaint`. Explicitly return `null` for any field that cannot be determined from the text.
#
# "This 'Everest Smartwatch' is amazing! The battery life is incredible, easily 5 stars. I'm really happy with this purchase, although the charging cable is a bit too short."
#
# ---

# %% [markdown]
# ### Q38 Prompt
#
# Classify the following customer complaint into one of three fixed categories: 'Billing', 'Product', or 'Delivery'. Identify the main issue, suggest a solution, and return the entire result as a single JSON object.
#
# "I received my order, 'Order #12345', yesterday, but the 'XYZ Monitor' I bought is cracked. I need a replacement as soon as possible, or a full refund."
#
# ---

# %% [markdown]
# ### Q39 Prompt
#
# Convert the plain-language business requirement: "Find all customers who spent more than $10,000 last month" into a CSV-style output. List five sample matching records with clearly labeled columns for `CustomerID`, `CustomerName`, and `TotalSpend`.
#
# ---

# %% [markdown]
# ### Q40 Prompt
#
# **Role:** Python Developer
#
# **Language:** Python 3
#
# **Task:** Write a function to check if a given number is a prime number.
#
# **Requirements:**
# - The function should be named `is_prime`.
# - It should accept one argument, an integer `n`.
# - It should return `True` if `n` is prime, and `False` otherwise.
# - It must include error handling for negative numbers or non-integer inputs, raising a `ValueError` with an appropriate message.
#
# **Input:** An integer.
#
# **Output:** A boolean (`True`/`False`) or a `ValueError`.
#
# ---

# %% [markdown]
# ### Q41 Prompt
#
# Explain the following Python code line by line to a complete beginner. For each line, explain both what it does and why it is used.
#
# ```python
# def calculate_average(numbers):
#     if not numbers:
#         return 0
#     total = sum(numbers)
#     return total / len(numbers)
# ```
#
# ---

# %% [markdown]
# ### Q42 Prompt
#
# **Buggy Code:**
#
# ```python
# def multiply_list(numbers):
#     product = 0
#     for num in numbers:
#         product *= num
#     return product
#
# print(multiply_list([1, 2, 3, 4]))
# ```
#
# **Error Message:** (Assume no error message, but an incorrect output)
#
# **Expected Output:** `24`
#
# **Task:** Explain the cause of the error in the provided Python code and provide the corrected code that produces the expected output.
#
# ---

# %% [markdown]
# ### Q43 Prompt
#
# Improve the performance of the following Python function while preserving its exact output. Explain the changes made using a before-and-after comparison.
#
# **Original Function:**
#
# ```python
# def sum_of_squares_slow(n):
#     result = 0
#     for i in range(n + 1):
#         result += i * i
#     return result
# ```
#
# ---

# %% [markdown]
# ### Q44 Prompt
#
# Refactor the following messy piece of Python code by adding proper functions, meaningful variable names, and PEP 8 formatting, without changing its final output.
#
# **Messy Code:**
#
# ```python
# def a(x,y):
#     r=0
#     for i in range(x):
#         for j in range(y):
#             r+=i*j
#     print(r)
#
# a(2,3)
# ```
#
# ---

# %% [markdown]
# ### Q45 Prompt
#
# Generate unit test cases for a Python function that calculates the average of a list of numbers, using Python's `unittest` framework. Include:
#
# -   3 normal cases (e.g., positive numbers, negative numbers, mixed numbers).
# -   2 edge cases (e.g., an empty list, a list with one element).
# -   2 invalid-input cases (e.g., list containing non-numeric values).
#
# Assume the function is named `calculate_average(numbers_list)`.
#
# ---

# %% [markdown]
# ### Q46 Prompt
#
# Convert the business requirement: "List all employees whose department is Sales and salary is above 60,000" into a correct SQL query. The table is named `employees` and has columns `employee_id`, `name`, `department`, and `salary`.
#
# ---

# %% [markdown]
# ### Q47 Prompt
#
# **Role:** Senior Data Analyst
#
# **Dataset Description:** You have a CSV file named `customer_transactions.csv` with 10,000 rows. It contains columns like `TransactionID` (unique identifier), `CustomerID`, `TransactionDate`, `ProductCategory`, `Amount` (float), `PaymentMethod`, and `ShippingAddress` (text field which sometimes contains incomplete addresses).
#
# **Task:** Describe the number of rows, columns, data types, missing values (identify potential columns), and possible data quality issues present in this dataset.
#
# ---

# %% [markdown]
# ### Q48 Prompt
#
# **Dataset Description:** Consider a dataset with the following columns and their potential missing value issues:
#
# -   `Age`: Contains approximately 5% missing values.
# -   `Income`: Has about 20% missing values, some of which might be `0` instead of `NaN`.
# -   `Email`: About 1% missing, but crucial for customer contact.
# -   `LastPurchaseDate`: Missing for new customers, which is expected.
#
# **Task:** For each column identified with missing values, suggest the most appropriate treatment method (e.g., imputation, deletion, specific handling) and briefly explain your reasoning.
#
# ---

# %% [markdown]
# ### Q49 Prompt
#
# **Sales Dataset:** You have a sales dataset with the following columns: `Date`, `Product`, `Region`, and `Revenue`. The dataset spans 2 years of daily sales records.
#
# **Task:** Identify important patterns, outliers, and relationships between variables through Exploratory Data Analysis (EDA). Specifically, consider:
# 1.  Sales trends over time (e.g., seasonality, growth).
# 2.  Top-performing products and regions.
# 3.  Any unusual spikes or drops in revenue.
# 4.  How product sales vary across regions.
#
# ---

# %% [markdown]
# ### Q50 Prompt
#
# **Sales Dataset:** (Same as Q49: `Date`, `Product`, `Region`, `Revenue`, 2 years of daily sales records)
#
# **Task:** Suggest three appropriate charts for this sales dataset. For each chart, state:
# 1.  The chart type (e.g., line chart, bar chart).
# 2.  What should be on the X-axis.
# 3.  What should be on the Y-axis.
# 4.  The specific business question each chart answers.
#
# ---

# %% [markdown]
# ### Q51 Prompt
#
# **Dataset Description:** You have a dataset where the target variable is 'Customer_Churn' (binary: 0 or 1), and features include `CustomerID`, `Age`, `Gender`, `Tenure`, `MonthlyCharges`, `TotalCharges`, `ContractType`, `InternetService`, and `PaymentMethod`.
#
# **Task:** Suggest suitable machine learning algorithms for predicting customer churn. For each algorithm:
# 1.  Explain why it is appropriate for this problem.
# 2.  Outline key preprocessing steps required for the dataset.
# 3.  Recommend relevant evaluation metrics to assess model performance.
#
# ---

# %% [markdown]
# ### Q52 Prompt
#
# **Business Insight Task:** Analyze a dataset (assume you have access to a comprehensive e-commerce sales and customer data, including purchase history, demographics, website activity) from a business perspective. Identify important trends, potential risks, new opportunities, and recommend actionable strategies. Do not just describe statistics; provide interpretations that drive business decisions.
#
# ---

# %% [markdown]
# ### Q53 Prompt (Full Data Analysis Prompt Template)
#
# ```
# **Role:** Act as a [Role, e.g., 'Lead Data Scientist', 'Business Intelligence Analyst'].
#
# **Dataset Description:**
# [Provide a concise description of the dataset, including its source, size, key columns, and what it represents. Example: 'You have a CSV file named `sales_data.csv` with 50,000 rows, containing transaction-level data including Date, ProductID, CustomerID, Region, and Revenue.']
#
# **Business Objective:**
# [Clearly state the main business question or goal to be achieved through this analysis. Example: 'Identify the top 5 performing products and regions to optimize marketing spend for the next quarter.']
#
# **Tasks:**
# 1.  **Data Loading & Initial Inspection:** Load the dataset and provide a summary of its structure (head, info, describe).
# 2.  **Data Cleaning:** Identify and propose treatment for any missing values, duplicates, or incorrect data types.
# 3.  **Exploratory Data Analysis (EDA):** Perform EDA to uncover trends, outliers, and relationships. Focus on [specify 2-3 key areas of focus, e.g., 'time-based sales trends', 'customer segmentation', 'product performance by region'].
# 4.  **Key Insights & Recommendations:** Summarize your most important findings and provide actionable business recommendations based on the analysis. Present these as a bulleted list.
# 5.  **Visualization Suggestions:** Suggest 2-3 appropriate visualizations to communicate key insights, specifying chart type, axes, and the insight each conveys.
#
# **Constraints (Optional):**
# -   [Any specific tools to use, e.g., 'Only use Pandas and Matplotlib.']
# -   [Any output format preferences, e.g., 'Present all code in Python cells and explanations in Markdown.']
# -   [Word limits for explanations, etc.]
#
# ```
#
# ---
